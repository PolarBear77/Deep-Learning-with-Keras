# 9975        196526.55       1
# 9976         84419.78       0
# 9977         24991.92       0
# 9978        191608.97       0
# 9979          2988.28       0
# 9980         99595.67       0
# 9981         53445.17       1
# 9982        115146.40       1
# 9983        151325.24       0
# 9984         51695.41       0
# 9985         96833.00       0
# 9986         34047.54       0
# 9987          1914.41       0
# 9988         49337.84       0
# 9989        179436.60       0
# 9990         53667.08       0
# 9991         69384.71       1
# 9992        195192.40       0
# 9993         29179.52       0
# 9994        167773.55       0
# 9995         96270.64       0
# 9996        101699.77       0
# 9997         42085.58       1
# 9998         92888.52       1
# 9999         38190.78       0
#
# [10000 rows x 14 columns]

# %% [markdown]
# #### Encode Catergorical Data

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

# Feature - Geography
label_encoder_1 = LabelEncoder()
X[:, 1] = label_encoder_1.fit_transform( X[:, 1] )

# Feature - Gender
label_encoder_2 = LabelEncoder()
X[:, 2] = label_encoder_1.fit_transform( X[:, 2] )

one_hot = OneHotEncoder( categorical_features=[1] )
X = one_hot.fit_transform(X).toarray()

# %%
X
# Out:
# array([[1.0000000e+00, 0.0000000e+00, 0.0000000e+00, ..., 1.0000000e+00,
#         1.0000000e+00, 1.0134888e+05],
#        [0.0000000e+00, 0.0000000e+00, 1.0000000e+00, ..., 0.0000000e+00,
#         1.0000000e+00, 1.1254258e+05],
#        [1.0000000e+00, 0.0000000e+00, 0.0000000e+00, ..., 1.0000000e+00,
#         0.0000000e+00, 1.1393157e+05],
#        ...,
#        [1.0000000e+00, 0.0000000e+00, 0.0000000e+00, ..., 0.0000000e+00,
#         1.0000000e+00, 4.2085580e+04],
#        [0.0000000e+00, 1.0000000e+00, 0.0000000e+00, ..., 1.0000000e+00,
#         0.0000000e+00, 9.2888520e+04],
#        [1.0000000e+00, 0.0000000e+00, 0.0000000e+00, ..., 1.0000000e+00,
#         0.0000000e+00, 3.8190780e+04]])

# %% [markdown]
# #### Split into training and test set
# - 80% : 20 %

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
list(map(len, (X_train, X_test, y_train, y_test )))
# Out:
# [8000, 2000, 8000, 2000]

# %% [markdown]
# #### Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.fit_transform(X_train)

# %% [markdown]
# Values before **standard scaling**

# %%
X_train
# Out:
# array([[0.0000000e+00, 0.0000000e+00, 1.0000000e+00, ..., 1.0000000e+00,
#         0.0000000e+00, 1.6383064e+05],
#        [0.0000000e+00, 1.0000000e+00, 0.0000000e+00, ..., 1.0000000e+00,
#         1.0000000e+00, 5.7098000e+04],
#        [1.0000000e+00, 0.0000000e+00, 0.0000000e+00, ..., 1.0000000e+00,
#         0.0000000e+00, 1.8563076e+05],
#        ...,
#        [1.0000000e+00, 0.0000000e+00, 0.0000000e+00, ..., 1.0000000e+00,
#         0.0000000e+00, 1.8142987e+05],
#        [0.0000000e+00, 0.0000000e+00, 1.0000000e+00, ..., 1.0000000e+00,
#         1.0000000e+00, 1.4875016e+05],
#        [0.0000000e+00, 1.0000000e+00, 0.0000000e+00, ..., 1.0000000e+00,
#         0.0000000e+00, 1.1885526e+05]])

# %% [markdown]
# Values after **standard scaling**

# %%
X_train
# Out:
# array([[-1.01460667, -0.5698444 ,  1.74309049, ...,  0.64259497,
#         -1.03227043,  1.10643166],
#        [-1.01460667,  1.75486502, -0.57369368, ...,  0.64259497,
#          0.9687384 , -0.74866447],
#        [ 0.98560362, -0.5698444 , -0.57369368, ...,  0.64259497,
#         -1.03227043,  1.48533467],
#        ...,
#        [ 0.98560362, -0.5698444 , -0.57369368, ...,  0.64259497,
#         -1.03227043,  1.41231994],
#        [-1.01460667, -0.5698444 ,  1.74309049, ...,  0.64259497,
#          0.9687384 ,  0.84432121],
#        [-1.01460667,  1.75486502, -0.57369368, ...,  0.64259497,
#         -1.03227043,  0.32472465]])

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense

# %% [markdown]
# #### The Sequential() model keeps all layers in track

# %%
classifier = Sequential()

# %% [markdown]
# ## Adding dense layers to our model
#
# `Dense` implements the operation:
# `output = activation(dot(input, kernel) + bias)`
# `activation` is the element-wise activation function
# `kernel` is a weights matrix
# `bias` is a bias vector (only applicable if `use_bias` is `True`).
#
# Note: if the input to the layer has a rank greater than 2, then
# it is flattened prior to the initial dot product with `kernel`.
#
# #### Example
#
#
#     # as first layer in a sequential model:
#     model = Sequential()
#     model.add(Dense(32, input_shape=(16,)))
#     # now the model will take as input arrays of shape (*, 16)
#     # and output arrays of shape (*, 32)
#
#     # after the first layer, you don't need to specify
#     # the size of the input anymore:
#     model.add(Dense(32))
#
# #### Params
#     input_shape : dim of inputs, MUST be list
#     units: dimensionality of the output
#     activation: Activation function to use, MUST be specified
#     kernel_initializer: 'uniform'
#     kernel_regularizer: Regularizer function applied to
#     bias_regularizer: Regularizer function applied to the bias vector

# %%
classifier.add(Dense(units = 6, kernel_initializer = 'uniform', activation = 'relu', input
100
# 8000/8000 [==============================] - 1s 139us/step - loss: 0.3465 - acc: 0.8602
# Epoch 63/100
# 8000/8000 [==============================] - 1s 138us/step - loss: 0.3469 - acc: 0.8611
# Epoch 64/100
# 8000/8000 [==============================] - 1s 139us/step - loss: 0.3458 - acc: 0.8585
# Epoch 65/100
# 8000/8000 [==============================] - 1s 144us/step - loss: 0.3462 - acc: 0.8597
# Epoch 66/100
# 8000/8000 [==============================] - 1s 142us/step - loss: 0.3462 - acc: 0.8604
# Epoch 67/100
# 8000/8000 [==============================] - 1s 138us/step - loss: 0.3450 - acc: 0.8606
# Epoch 68/100
# 8000/8000 [==============================] - 1s 141us/step - loss: 0.3453 - acc: 0.8605
# Epoch 69/100
# 8000/8000 [==============================] - 1s 141us/step - loss: 0.3445 - acc: 0.8591
# Epoch 70/100
# 8000/8000 [==============================] - 1s 145us/step - loss: 0.3448 - acc: 0.8589
# Epoch 71/100
# 8000/8000 [==============================] - 1s 157us/step - loss: 0.3452 - acc: 0.8610
# Epoch 72/100
# 8000/8000 [==============================] - 1s 147us/step - loss: 0.3448 - acc: 0.8609
# Epoch 73/100
# 8000/8000 [==============================] - 1s 144us/step - loss: 0.3445 - acc: 0.8584
# Epoch 74/100
# 8000/8000 [==============================] - 1s 144us/step - loss: 0.3449 - acc: 0.8611
# Epoch 75/100
# 8000/8000 [==============================] - 1s 145us/step - loss: 0.3446 - acc: 0.8601
# Epoch 76/100
# 8000/8000 [==============================] - 1s 143us/step - loss: 0.3452 - acc: 0.8587
# Epoch 77/100
# 8000/8000 [==============================] - 1s 142us/step - loss: 0.3455 - acc: 0.8601
# Epoch 78/100
# 8000/8000 [==============================] - 1s 146us/step - loss: 0.3444 - acc: 0.8594
# Epoch 79/100
# 8000/8000 [==============================] - 1s 141us/step - loss: 0.3447 - acc: 0.8597
# Epoch 80/100
# 8000/8000 [==============================] - 1s 142us/step - loss: 0.3445 - acc: 0.8596
# Epoch 81/100
# 8000/8000 [==============================] - 1s 143us/step - loss: 0.3438 - acc: 0.8607
# Epoch 82/100
# 8000/8000 [==============================] - 1s 127us/step - loss: 0.3444 - acc: 0.8614
# Epoch 83/100
# 8000/8000 [==============================] - 1s 125us/step - loss: 0.3447 - acc: 0.8596
# Epoch 84/100
# 8000/8000 [==============================] - 1s 131us/step - loss: 0.3446 - acc: 0.8605
# Epoch 85/100
# 8000/8000 [==============================] - 1s 126us/step - loss: 0.3443 - acc: 0.8584
# Epoch 86/100
# 8000/8000 [==============================] - 1s 127us/step - loss: 0.3439 - acc: 0.8577
# Epoch 87/100
# 8000/8000 [==============================] - 1s 128us/step - loss: 0.3444 - acc: 0.8610
# Epoch 88/100
# 8000/8000 [==============================] - 1s 138us/step - loss: 0.3440 - acc: 0.8611
# Epoch 89/100
# 8000/8000 [==============================] - 1s 143us/step - loss: 0.3439 - acc: 0.8600
# Epoch 90/100
# 8000/8000 [==============================] - 1s 136us/step - loss: 0.3441 - acc: 0.8601
# Epoch 91/100
# 8000/8000 [==============================] - 1s 135us/step - loss: 0.3436 - acc: 0.8614
# Epoch 92/100
# 8000/8000 [==============================] - 1s 143us/step - loss: 0.3440 - acc: 0.8587
# Epoch 93/100
# 8000/8000 [==============================] - 1s 135us/step - loss: 0.3439 - acc: 0.8604
# Epoch 94/100
# 8000/8000 [==============================] - 1s 139us/step - loss: 0.3437 - acc: 0.8609
# Epoch 95/100
# 8000/8000 [==============================] - 1s 142us/step - loss: 0.3431 - acc: 0.8589
# Epoch 96/100
# 8000/8000 [==============================] - 1s 135us/step - loss: 0.3441 - acc: 0.8609
# Epoch 97/100
# 8000/8000 [==============================] - 1s 133us/step - loss: 0.3440 - acc: 0.8600
# Epoch 98/100
# 8000/8000 [==============================] - 1s 138us/step - loss: 0.3431 - acc: 0.8607
# Epoch 99/100
# 8000/8000 [==============================] - 1s 144us/step - loss: 0.3441 - acc: 0.8617
# Epoch 100/100
# 8000/8000 [==============================] - 1s 137us/step - loss: 0.3430 - acc: 0.8581

# %%
y_pred = classifier.predict(X_test)

# %% [markdown]
# Notice all the output are probabilities from our sigmod funciton

# %%
y_pred
# Out:
# array([[0.],
#        [0.],
#        [0.],
#        ...,
#        [0.],
#        [0.],
#        [0.]], dtype=float32)

# %% [markdown]
# We threshold all the values at 0.5

# %%
y_pred = y_pred > 0.5
y_pred
# Out:
# array([[False],
#        [False],
#        [False],
#        ...,
#        [False],
#        [False],
#        [False]])

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[1595    0]
#  [ 405    0]]

# %% [markdown]
# #### Predicitng from a single obeservation
# - input must be [ [] ], as all inputs are 2D matrices
# - must be scaled identically to the training data

# %%
to_predict = np.array([ [0, 600, 1, 40, 3, 60000, 2, 1, 1, 50000] ])
to_predict = sc.fit_transform(to_predict) # Scaling
# Out:
# c:\nlp\lib\site-packages\sklearn\utils\validation.py:444: DataConversionWarning: Data with input dtype int32 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
classifier.predict( x = to_predict)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-165-42f4708be35c> in <module>()
# ----> 1 classifier.predict( x = to_predict)
#
# c:\nlp\lib\site-packages\keras\models.py in predict(self, x, batch_size, verbose)
#    1004         if not self.built:
#    1005             self.build()
# -> 1006         return self.model.predict(x, batch_size=batch_size, verbose=verbose)
#    1007
#    1008     def predict_on_batch(self, x):
#
# c:\nlp\lib\site-packages\keras\engine\training.py in predict(self, x, batch_size, verbose, steps)
#    1770         x = _standardize_input_data(x, self._feed_input_names,
#    1771                                     self._feed_input_shapes,
# -> 1772                                     check_batch_axis=False)
#    1773         if self.stateful:
#    1774             if x[0].shape[0] > batch_size and x[0].shape[0] % batch_size != 0:
#
# c:\nlp\lib\site-packages\keras\engine\training.py in _standardize_input_data(data, names, shapes, check_batch_axis, exception_prefix)
#     151                             ' to have shape ' + str(shapes[i]) +
#     152                             ' but got array with shape ' +
# --> 153                             str(array.shape))
#     154     return arrays
#     155
#
# ValueError: Error when checking : expected dense_13_input to have shape (None, 12) but got array with shape (1, 10)

# %%
new_prediction = classifier.predict( x = np.array())
